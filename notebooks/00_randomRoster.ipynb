# %%
import random
import pandas as pd

# %%
df=pd.DataFrame(columns=['Presentation Number', 'Presenter'])
roster=['Gilbert Espinoza','Mikala Everett','Ashley Hernandez','Zachary Hojeibane','Megan Kim','Riley Knowles',
        'Harsh Pendse','Samantha Racine','Ritika Ramesh','Jace Steiner','Xinquan Xu','Betty Yang']

random.shuffle(roster)


for i, s in enumerate(roster):
    print(s)
    df.loc[len(df)]=[i+1, s]
df.to_csv('LabReport1_PresentationOrder.csv', index=False)
# Out:
# Zachary Hojeibane
# Riley Knowles
# Megan Kim
# Jace Steiner
# Gilbert Espinoza
# Ritika Ramesh
# Betty Yang
# Mikala Everett
# Ashley Hernandez
# Harsh Pendse
# Samantha Racine
# Xinquan Xu

# %%
import random
import pandas as pd

# %%
df=pd.DataFrame(columns=['Presentation Number', 'Presenter'])
roster=['Michael Bove','Maya Davis','Dahlia James','Michael Persson']

random.shuffle(roster)

term='26fa'
filename=f'LabReport1_PresentationOrder_{term}.csv'
for i, s in enumerate(roster):
    print(s)
    df.loc[len(df)]=[i+1, s]

df.to_csv(filename, index=False)
# Out:
# Michael Bove
# Maya Davis
# Dahlia James
# Michael Persson

# %%
import datetime as dt

# %%
curr_year=str(dt.date.today().year -1)+'70'
curr_year
# Out:
# '202570'

# %%
term='26fa'
f'LabReport1_PresentationOrder_{term}.csv'
# Out:
# 'LabReport1_PresentationOrder_26fa.csv'

# %% [markdown]
# # Working with Data in Python

# %% [raw]
# to work with data, we'll first need to import some libraries. Libraries are basically packages of code that someone has already written and made available for you to use.
# A major library that we'll be using is called pandas. Pandas allows us to structure data in a tabular format (rows and columns) similar to Excel. Once we import it, we'll also give it an alias. The alias allows us to call pandas by a shorter name in our code.
# import pandas
# Now that we've imported the library, we have access to all the cool things pandas has to offer. The flagship data class that pandas offers is the DataFrame. The DataFrame is basically a table. It has rows, columns, and the columns have headers (column names). Let's import some data from NYC Open Data and start working with it.
#
# read data set (via url)
#
# count the number of rows
#
# view the column names
#
# view data types
#
# change a data type of a column
#
# get some summary statistics of quantitative columns
#
# sort values
#
# clean up some messy values
#
# aggregate - mean, max, median. groupby and agg
#
# slice
#
# iterrate - find some value and print the index
#
# create a new column
#
# engineer a feature
#
# create several dataframes in a dictionary?
#
# basic data visualization - seaborn
# histogram, density plot,
# barplot
#
# create some workflow to do all of the above in one shot. print statements along the way to show progress.
#
# export csv when we're done.
#
# show how to read csv that isn't available via url

# %%
import pandas as pd

url='https://docs.google.com/spreadsheets/d/1xcsd8bKujnnvetAwGBzBl3w6NhxxMkRvwDn7jxGDUwg/edit?usp=sharing'

path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
#df = pd.read_csv(path)
path
# Out:
# 'https://drive.google.com/uc?export=download&id=1xcsd8bKujnnvetAwGBzBl3w6NhxxMkRvwDn7jxGDUwg'

# %%
file_id
# Out:
# '1xcsd8bKujnnvetAwGBzBl3w6NhxxMkRvwDn7jxGDUwg'

# %%
download_url
# Out:
# 'https://drive.google.com1xcsd8bKujnnvetAwGBzBl3w6NhxxMkRvwDn7jxGDUwg'

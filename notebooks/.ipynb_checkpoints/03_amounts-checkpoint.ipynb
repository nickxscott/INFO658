# %%
import pandas as pd
import numpy as np
from scipy import stats
from datetime import date, datetime, timedelta

import seaborn as sns
import matplotlib.pyplot as plt

import yfinance as yf

import os
import base64
from dotenv import load_dotenv
import snowflake.connector as snw


with open("../../../snowflake_env/scottn_snowflake_stjohns/scottn_snowflake_stjohns.pem", "r") as key:
    p_key=key.read()
p_key=p_key.replace("-----BEGIN PRIVATE KEY-----", "").replace("-----END PRIVATE KEY-----", "").strip()
p_key=base64.b64decode(p_key)

load_dotenv('../../../snowflake_env/snowflake.env')
uid_snow=os.getenv('uid_snow')
print('done')

def get_sql(pk:bytes=None,uid_snow: str=None,pwd_snow: str=None,query: str=None,sql_path: str=None,account_snow: str='stjohns.us-east-1',
            database: str='banner',schema: str='saturn',no_return: bool=False,**kwargs) -> pd.DataFrame:
    #Retrieves a given query entered as a file (sql_path) or a string (query)
    #Must supply either an environment file path location (Devs)
    #Or a user id and password (Prod)
    if (pk==None and (uid_snow==None or pwd_snow==None)):
        raise ValueError("Must Provide environment path location or both user id and password to snowflake")
    if pk==None:
        ctx = snw.connect(
            user=uid_snow,
            password=pwd_snow,
            account=account_snow
        )
    else:
        ctx = snw.connect(
            user=uid_snow,
            account=account_snow,
            private_key=pk
        )
    cs = ctx.cursor()
    cs.execute("USE DATABASE "+database+";")
    cs.execute("USE SCHEMA " + schema + ";")
    if sql_path:
        f=open(sql_path)
        query_main="".join(f.readlines())
        f.close()
    else:
        query_main=query
    if kwargs!={}:
        s=list(kwargs.values())
        query_main=query_main.format(*s)
    cs.execute(query_main)
    if no_return:
        D=pd.DataFrame({'Result':['OK']}) 
    else:
        D = cs.fetchall()
        col_nms=[x.name for x in cs.description]
        if col_nms==[]:
            pass
        else:
            D=pd.DataFrame(D,index=None)
            D.columns=col_nms
    cs.close()
    ctx.close()
    return D
# Out:
# C:\Users\scottn\Anaconda3\envs\SJU_DS\lib\site-packages\snowflake\connector\options.py:103: UserWarning: You have an incompatible version of 'pyarrow' installed (17.0.0), please install a version that adheres to: 'pyarrow<10.1.0,>=10.0.1; extra == "pandas"'
#   warn_incompatible_dep(
# done

# %%
df_marketcap=pd.DataFrame(columns=['Company', 'Market Cap', 'mc_raw'])
for t in ['MSFT', 'AAPL', 'AMZN', 'TSLA', 'NVDA', 'META', 'GOOG']:
    data=yf.Ticker(t)
    mc=data.info['marketCap']
    comp=data.info['shortName']
    df_marketcap.loc[len(df_marketcap)]=[comp, f"${mc:,.2f}", mc]
df_marketcap=df_marketcap.sort_values(by='mc_raw', ascending=False)
df_marketcap[['Company','Market Cap']]
# Out:
#                  Company             Market Cap
# 4     NVIDIA Corporation  $4,490,682,957,824.00
# 6          Alphabet Inc.  $4,072,855,568,384.00
# 1             Apple Inc.  $3,836,162,605,056.00
# 0  Microsoft Corporation  $3,471,437,201,408.00
# 2       Amazon.com, Inc.  $2,590,239,358,976.00
# 5   Meta Platforms, Inc.  $1,584,744,497,152.00
# 3            Tesla, Inc.  $1,484,429,459,456.00

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.despine(top=True,right=True)
ax=sns.barplot(data=df_marketcap, y='Company', x='mc_raw')
ax.set(ylabel='', xlabel='Market Capitalization ($ Trillions)');
#ax.tick_params(axis='both', which='both', length=0)
ax.xaxis.grid(True)

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.despine(top=True,right=True)
ax=sns.barplot(data=df_marketcap, x='Company', y='mc_raw')
ax.set(xlabel='', ylabel='Market Capitalization ($ Trillions)')
ax.tick_params(axis='x', rotation=45);

# %%
df=get_sql(pk=p_key,uid_snow=uid_snow, sql_path='sql/enrlGender.sql')
#df_bar=df.groupby(['COLLEGE', 'SPBPERS_SEX']).PIDM.count().reset_index(name='ct')
df=df.rename(columns={'SPBPERS_SEX':'Gender'})
df
# Out:
#            PIDM REG_TERM Gender                COLLEGE          LEVEL
# 0      93567366   202570      M   Professional Studies  Undergraduate
# 1      93567951   202570      F  Liberal Arts/Sciences  Undergraduate
# 2      93568341   202570      M   Professional Studies  Undergraduate
# 3      93572410   202570      F     School of Business  Undergraduate
# 4      93572745   202570      M   Professional Studies  Undergraduate
# ...         ...      ...    ...                    ...            ...
# 12456  93545527   202570      M     School of Business  Undergraduate
# 12457  93547514   202570      F   Professional Studies  Undergraduate
# 12458  93547643   202570      F  Liberal Arts/Sciences  Undergraduate
# 12459  93548354   202570      M     School of Pharmacy  Undergraduate
# 12460  93548419   202570      M     School of Business  Undergraduate
#
# [12461 rows x 5 columns]

# %%
# Define the custom order
df_order=df.groupby(['COLLEGE']).PIDM.count().reset_index(name='ct')
df_order=df_order.sort_values(by='ct', ascending=False)
custom_order=df_order.COLLEGE.tolist()

# Convert the 'Item' column to a Categorical with the specified order
df['COLLEGE'] = pd.Categorical(df['COLLEGE'], categories=custom_order, ordered=True)

fig, ax = plt.subplots(figsize=(7, 5))
sns.despine(top=True,right=True)
#ax=sns.barplot(data=df_bar, x='ct', y='College', hue='gender', multiple='stacked')
sns.histplot(df, y='COLLEGE', hue='Gender', multiple='stack');
ax.set(xlabel='', ylabel='', title='Fall 2025 Enrollment by College and Gender');
#ax.tick_params(axis='x', rotation=45);

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.despine(top=True,right=True)
sns.histplot(df, y='COLLEGE', hue='Gender', multiple='fill');
ax.set(xlabel='Proportion', ylabel='', title='Fall 2025 Enrollment by College and Gender');
#ax.tick_params(axis='x', rotation=45);

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.despine(top=True,right=True)
sns.histplot(df, y='Gender', hue='COLLEGE', multiple='fill');
ax.set(xlabel='Proportion', ylabel='', title='Fall 2025 Enrollment by College and Gender');
#ax.tick_params(axis='x', rotation=45);

# %%
# Define the custom order
df_order=df.groupby(['COLLEGE']).PIDM.count().reset_index(name='ct')
df_order=df_order.sort_values(by='ct', ascending=False)
custom_order=df_order.COLLEGE.tolist()

# Convert the 'Item' column to a Categorical with the specified order
df['COLLEGE'] = pd.Categorical(df['COLLEGE'], categories=custom_order, ordered=True)

df_facetBar=df.groupby(['Gender', 'LEVEL', 'COLLEGE']).PIDM.count().reset_index().rename(columns={'LEVEL':'Level'})

g = sns.FacetGrid(df_facetBar, col="Gender",  row="Level", height=4)
g.map_dataframe(sns.barplot, y="COLLEGE", x='PIDM')
g.set_axis_labels(x_var="", y_var="");

# %% [markdown]
# # Start at 0

# %%
df=get_sql(pk=p_key,uid_snow=uid_snow, sql_path='sql/enrlGender.sql')
#df_bar=df.groupby(['COLLEGE', 'SPBPERS_SEX']).PIDM.count().reset_index(name='ct')
df=df.rename(columns={'SPBPERS_SEX':'Gender'})
df
# Out:
#            PIDM REG_TERM Gender                COLLEGE          LEVEL
# 0      80070700   202570      F  Liberal Arts/Sciences       Graduate
# 1      80071034   202570      M   Professional Studies       Graduate
# 2      80071371   202570      F    School of Education       Graduate
# 3      93584034   202570      M  Liberal Arts/Sciences  Undergraduate
# 4      93584097   202570      M     School of Business  Undergraduate
# ...         ...      ...    ...                    ...            ...
# 12456  93555818   202570      M  Liberal Arts/Sciences  Undergraduate
# 12457  93290984   202570      F    School of Education       Graduate
# 12458  93556282   202570      M   Professional Studies  Undergraduate
# 12459  93556992   202570      F  Liberal Arts/Sciences  Undergraduate
# 12460  93557124   202570      F     School of Pharmacy  Undergraduate
#
# [12461 rows x 5 columns]

# %%
fig, ax = plt.subplots(2,1,figsize=(8, 10))
df_bar=df.groupby(['COLLEGE']).PIDM.count().reset_index()
df_bar=df_bar.sort_values(by='PIDM')

#starts at 0
sns.barplot(data=df_bar, y='COLLEGE', x='PIDM', ax=ax[0])


#doesnt start at 0
sns.barplot(data=df_bar, y='COLLEGE', x='PIDM', ax=ax[1]);

ax[1].set(xlim=(2000, 4000))
for i,a in enumerate(ax):
    ax[i].set(ylabel='', xlabel='', title='Fall 2025 Enrollment by College');

# %% [markdown]
# # Histograms

# %%
fig, ax = plt.subplots(1,3,figsize=(15, 5))
sns.despine(top=True,right=True)
#symmetric
rng = np.random.default_rng()
x=[rng.normal() for i in range(0,1000)]
sns.histplot(x=x, ax=ax[0]).set_title('Symmetric');

#skew
ticker='BBAI'
data = yf.download([ticker], period='2y')
sns.histplot(x=data['Close']['BBAI'], ax=ax[1]).set_title('Skewed')

#uniform
x=[rng.uniform() for i in range(0,10000)]
sns.histplot(x=x, ax=ax[2]).set_title('Uniform')

for i, a in enumerate(ax):
    ax[i].set(xlabel='', ylabel='');
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sns.despine(top=True,right=True)
rng = np.random.default_rng()
x=[rng.normal() for i in range(0,10000)]
sns.histplot(x=x, binwidth=0.25)
plt.axvline(x=np.mean(x), color='crimson', linestyle='--', alpha=0.8)
ax.set(ylabel='');

# %%
fig, ax = plt.subplots(1,3,figsize=(15, 5), sharex=True)
sns.despine(top=True,right=True)
rng = np.random.default_rng()

#low
x=rng.normal(loc=0, scale=1, size=10000)
sns.histplot(x=x, binwidth=0.5, ax=ax[0])

#mid
x=rng.normal(loc=0, scale=2, size=10000)
sns.histplot(x=x, binwidth=0.75, ax=ax[1])

#high
x=rng.normal(loc=0, scale=3, size=10000)
sns.histplot(x=x, binwidth=1, ax=ax[2])

for i, a in enumerate(ax):
    ax[i].set(xlabel='', ylabel='');

# %%
x=rng.normal(loc=0, scale=1, size=10000)
ax=sns.histplot(x=x, binwidth=0.5,kde=True, line_kws={'color':'crimson', 'alpha':0.8})
sns.despine(top=True,right=True)
ax.set(ylabel='');

# %%
df_height=pd.DataFrame(columns=['gender', 'height'])
for i in range(0,10000):
    #f=np.random.binomial(10, 0.2)
    #m=np.random.binomial(10, 0.8)
    f=rng.normal(loc=5, scale=1)
    m=rng.normal(loc=6, scale=1)
    df_height.loc[len(df_height)]=['male', m]
    df_height.loc[len(df_height)]=['female', f]

sns.histplot(data=df_height, x='height', multiple='layer', binwidth=1);

# %%
rng = np.random.default_rng()

df_fem=pd.DataFrame(columns=['gender', 'height'])
df_male=pd.DataFrame(columns=['gender', 'height'])

f=rng.normal(loc=5, scale=0.25, size=10000)
m=rng.normal(loc=6, scale=0.25, size=10000)

df_fem.height=f
df_fem.gender='female'
df_male.height=m
df_male.gender='male'
df_height=pd.concat([df_fem, df_male])

ax=sns.histplot(data=df_height, x='height', multiple='layer')
#alternative with groups
ax=sns.histplot(data=df_height, x='height', hue='gender', multiple='stack')
sns.despine(top=True,right=True)
ax.set(ylabel='');

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5))
sns.despine(top=True,right=True)

#female
sns.histplot(data=df_fem, x='height', binwidth=0.1, ax=ax[0])
ax[0].set(ylabel='', xlabel='', title='Male Participants')
#male
sns.histplot(data=df_male, x='height', binwidth=0.1, ax=ax[1])
ax[1].set(ylabel='', xlabel='', title='Female Participants');

# %%
df_fem=pd.DataFrame(columns=['gender', 'height'])
df_male=pd.DataFrame(columns=['gender', 'height'])

f=rng.normal(loc=5, scale=0.25, size=10000)
m=rng.normal(loc=6, scale=0.25, size=10000)

df_fem.height=f
df_fem.gender='female'
df_male.height=m
df_male.gender='male'
df_height=pd.concat([df_fem, df_male])

#x=sns.histplot(data=df_height, x='height', multiple='layer')
#alternative with groups
ax=sns.kdeplot(data=df_height, x='height', hue='gender', fill=True)
sns.despine(top=True,right=True)
ax.set(ylabel='');

# %%
sns.boxplot(data=df_height, x='height', hue='gender', fliersize=2)
sns.despine(top=True,right=True);

# %%
sns.violinplot(data=df_height, y='height', x='gender', hue='gender', inner=None)
sns.despine(top=True,right=True);

# %%
sns.swarmplot(data=df_height.sample(frac=0.1), y='height', x='gender', size=2)
sns.despine(top=True,right=True);

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.despine(top=True,right=True);

sns.violinplot(data=df_height, y='height', x='gender', hue='gender', inner=None, fill=False, ax=ax)


# 2. Overlay the swarm plot
sns.swarmplot(data=df_height.sample(frac=0.1), y='height', x='gender', hue='gender', size=2, ax=ax)

ax.set(xlabel='');
